# %%
hi

# %%
df_bronze = spark.readStream \
    .format("cloudFiles") \
    .option("cloudFiles.format", "csv") \
    .option("cloudFiles.schemaLocation", "/schemas/bronze_sales") \
    .option("header", "true") \
    .load("/mnt/raw/sales")

# %%
df_bronze = spark.readStream \
    .format("cloudFiles") \
    .option("cloudFiles.format", "csv") \
    .option("header", "true") \
    .option("cloudFiles.schemaLocation", "dbfs:/FileStore/schemas/bronze_sales") \
    .load("dbfs:/FileStore/raw/sales")

# %%
df_silver = spark.read.format("delta") \
    .load("/delta/bronze_sales")

# %%
df_silver

# %%
from pyspark.sql.functions import col

df_silver_clean = df_silver \
    .dropna() \
    .withColumn("amount", col("amount").cast("double"))

# %%
spark.read.format("csv") \
    .option("header", "true") \
    .load("dbfs:/FileStore/raw/sales") \
    .show()
