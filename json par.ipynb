# %%
json_path = "/Volumes/workspace/product/productt/20 MB.json"

# %%
df_json = (
    spark.read
    .option("multiline", "true")
    .json(json_path)
)

# %%
display(df_json)

# %%
df_flat = df_json.select("employee.*")
display(df_flat)

# %%
df_flat_dep=df_flat.select("projects")
display(df_flat_dep)

# %%
parquet_path = "/Volumes/workspace/product/productt/parquet/employee_parquet"

df_flat.write \
    .mode("overwrite") \
    .parquet(parquet_path)

# %%
df_parquet = spark.read.parquet(parquet_path)
display(df_parquet)
df = spark.read.json(json_path)
